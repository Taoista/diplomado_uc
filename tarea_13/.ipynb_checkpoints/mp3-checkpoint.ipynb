# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE


# %matplotlib notebook

# %% [markdown]
# #### Importacion de DB ventas transbank

# %%
tbk = pd.read_csv('transbank.csv',encoding = "ISO-8859-1")

# %% [markdown]
# #### verificacion de datos importados

# %%
tbk.head()
# Out:
#    id ws_token  oc   total     estado  response       fecha fetchtbk  cod_aut  \
# 0   1      NaN  82  213763  pendiente       0.0  18/05/2020      NaN      NaN
# 1   2      NaN  83  100321  pendiente       0.0  18/05/2020      NaN      NaN
# 2   3      NaN  84  297080  pendiente       0.0  18/05/2020      NaN      NaN
# 3   4      NaN  85  297080  pendiente       0.0  18/05/2020      NaN      NaN
# 4   5      NaN  86  297080  pendiente       0.0  18/05/2020      NaN      NaN
#
#   t_tarjeta  n_ctas  c_ctas  n_tarjetas
# 0       NaN     NaN     NaN         NaN
# 1       NaN     NaN     NaN         NaN
# 2       NaN     NaN     NaN         NaN
# 3       NaN     NaN     NaN         NaN
# 4       NaN     NaN     NaN         NaN

# %% [markdown]
# #### 1 - verificar datos NAN y reemplazarlos

# %%
tbk.isna().sum()
# Out:
# id               0
# ws_token       655
# oc               0
# total            0
# estado           0
# response       626
# fecha            0
# fetchtbk       730
# cod_aut        731
# t_tarjeta      730
# n_ctas         730
# c_ctas        1059
# n_tarjetas     730
# dtype: int64

# %% [markdown]
# #### 2 - chambiar NaN a 0

# %%
tbk =tbk.fillna(0)

# %%
tbk.head()
# Out:
#     id                                           ws_token   oc   total  \
# 49  50  ea8ea12a1712cb93a846f906833d3e387ed807192b84e1...  131  254420
# 56  57  e392c21addcd253d213a325f220103406d0ad928c97ac6...  139  254420
# 57  58  e5a171c23445daf69d361159262be7f066e88e3990793f...  140  254420
# 58  59  ed65a3e236f7f87e45cbcac629e2ea50f6d5593e96e408...  141  254420
# 59  60  ef44b8d490f00661a611c6d112351a8ceebd25ecf67f56...  142  254420
#
#     estado  response                       fetchtbk   cod_aut t_tarjeta  \
# 49       1       0.0  2020-06-15T14:03:43.118-04:00  194884.0        VD
# 56       1       0.0  2020-06-15T14:18:45.988-04:00  999429.0        VD
# 57       1       0.0  2020-06-15T14:20:13.448-04:00  590542.0        VD
# 58       1       0.0  2020-06-15T14:25:38.911-04:00  755976.0        VD
# 59       1       0.0  2020-06-15T15:11:43.928-04:00  159123.0        VD
#
#     n_ctas  c_ctas  n_tarjetas
# 49     0.0     0.0         1.0
# 56     0.0     0.0         1.0
# 57     0.0     0.0         1.0
# 58     0.0     0.0         1.0
# 59     0.0     0.0         1.0

# %%
tbk.describe(include="all")
# Out:
#                  id                                           ws_token  \
# count    497.000000                                                497
# unique          NaN                                                484
# top             NaN  1131d755e4cc84852287611903227c4a737dcdbc14138f...
# freq            NaN                                                  3
# mean     583.044266                                                NaN
# std      327.895584                                                NaN
# min       50.000000                                                NaN
# 25%      275.000000                                                NaN
# 50%      565.000000                                                NaN
# 75%      881.000000                                                NaN
# max     1151.000000                                                NaN
#
#                  oc         total      estado    response  fetchtbk  \
# count    497.000000  4.970000e+02  497.000000  497.000000     497.0
# unique          NaN           NaN         NaN         NaN     389.0
# top             NaN           NaN         NaN         NaN       0.0
# freq            NaN           NaN         NaN         NaN      97.0
# mean     684.655936  4.860681e+05    0.802817   -0.313883       NaN
# std      341.040368  5.850381e+05    0.398273    0.741938       NaN
# min        0.000000  1.000000e+00    0.000000   -4.000000       NaN
# 25%      365.000000  1.851280e+05    1.000000    0.000000       NaN
# 50%      667.000000  3.203810e+05    1.000000    0.000000       NaN
# 75%      994.000000  5.825250e+05    1.000000    0.000000       NaN
# max     1272.000000  7.372286e+06    1.000000    0.000000       NaN
#
#               cod_aut t_tarjeta      n_ctas         c_ctas   n_tarjetas
# count      497.000000       497  497.000000     497.000000   497.000000
# unique            NaN         6         NaN            NaN          NaN
# top               NaN        VD         NaN            NaN          NaN
# freq              NaN       267         NaN            NaN          NaN
# mean    254586.331992       NaN    1.162978   24182.064386  2754.265594
# std     288854.408050       NaN    2.726734   70756.722572  2956.686949
# min          0.000000       NaN    0.000000       0.000000     0.000000
# 25%       3571.000000       NaN    0.000000       0.000000     1.000000
# 50%     153769.000000       NaN    0.000000       0.000000  1111.000000
# 75%     434399.000000       NaN    0.000000       0.000000  4421.000000
# max     999429.000000       NaN   12.000000  580622.000000  9858.000000

# %%
tbk.isna().sum()
# Out:
# id            0
# ws_token      0
# oc            0
# total         0
# estado        0
# response      0
# fetchtbk      0
# cod_aut       0
# t_tarjeta     0
# n_ctas        0
# c_ctas        0
# n_tarjetas    0
# dtype: int64

# %% [markdown]
# #### 2 - se reemplazan los datos del de la variable "estado", ya que contenia 3 descripciones y solo necesitaba si esta Aceptada = 1 o Rechazada 0

# %%
tbk['estado'].replace(["rechazado"],["rechazada"],inplace=True)

# %%
tbk['estado'].replace(["pendiente"],[0],inplace=True)

# %%
tbk['estado'].replace(["rechazada"],[0],inplace=True)

# %%
tbk['estado'].replace(["aceptada"],[1],inplace=True)

# %% [markdown]
# #### 3 -  verifico los datos de las variabels

# %%
tbk.dtypes
# Out:
# id              int64
# ws_token       object
# oc              int64
# total           int64
# estado          int64
# response      float64
# fecha          object
# fetchtbk       object
# cod_aut       float64
# t_tarjeta      object
# n_ctas        float64
# c_ctas        float64
# n_tarjetas    float64
# dtype: object

# %% [markdown]
# #### 4 elimino la variable fecha ya que es el mismo datos de fetchtbk

# %%
tbk = tbk.drop(['fecha'], axis=1)

# %% [markdown]
# #### 5 se eliminaron tokens de codigo 0 ya que fueron errores y demos en su instalacion

# %%
tbk = tbk.drop(tbk[tbk["ws_token"] == 0].index)

# %%
tbk.head()
# Out:
#     id                                           ws_token   oc   total  \
# 49  50  ea8ea12a1712cb93a846f906833d3e387ed807192b84e1...  131  254420
# 56  57  e392c21addcd253d213a325f220103406d0ad928c97ac6...  139  254420
# 57  58  e5a171c23445daf69d361159262be7f066e88e3990793f...  140  254420
# 58  59  ed65a3e236f7f87e45cbcac629e2ea50f6d5593e96e408...  141  254420
# 59  60  ef44b8d490f00661a611c6d112351a8ceebd25ecf67f56...  142  254420
#
#     estado  response                       fetchtbk   cod_aut t_tarjeta  \
# 49       1       0.0  2020-06-15T14:03:43.118-04:00  194884.0        VD
# 56       1       0.0  2020-06-15T14:18:45.988-04:00  999429.0        VD
# 57       1       0.0  2020-06-15T14:20:13.448-04:00  590542.0        VD
# 58       1       0.0  2020-06-15T14:25:38.911-04:00  755976.0        VD
# 59       1       0.0  2020-06-15T15:11:43.928-04:00  159123.0        VD
#
#     n_ctas  c_ctas  n_tarjetas
# 49     0.0     0.0         1.0
# 56     0.0     0.0         1.0
# 57     0.0     0.0         1.0
# 58     0.0     0.0         1.0
# 59     0.0     0.0         1.0

# %%
tbk.isna().sum()
# Out:
# id            0
# ws_token      0
# oc            0
# total         0
# estado        0
# response      0
# fetchtbk      0
# cod_aut       0
# t_tarjeta     0
# n_ctas        0
# c_ctas        0
# n_tarjetas    0
# dtype: int64

# %%
demo = tbk.drop("ws_token",1)
# Out:
# C:\Users\taois\AppData\Local\Temp\ipykernel_8652\3912795315.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   demo = tbk.drop("ws_token",1)

# %%
demo
# Out:
#         id    oc    total  estado  response                       fetchtbk  \
# 49      50   131   254420       1       0.0  2020-06-15T14:03:43.118-04:00
# 56      57   139   254420       1       0.0  2020-06-15T14:18:45.988-04:00
# 57      58   140   254420       1       0.0  2020-06-15T14:20:13.448-04:00
# 58      59   141   254420       1       0.0  2020-06-15T14:25:38.911-04:00
# 59      60   142   254420       1       0.0  2020-06-15T15:11:43.928-04:00
# ...    ...   ...      ...     ...       ...                            ...
# 1145  1146  1267   389801       1       0.0  2022-06-28T09:48:26.694-04:00
# 1147  1148  1269   109900       1       0.0  2022-06-28T15:25:50.355-04:00
# 1148  1149  1270  1869002       1       0.0  2022-06-28T20:34:45.153-04:00
# 1149  1150  1271   373800       1       0.0  2022-06-28T20:39:35.849-04:00
# 1150  1151  1272   219800       1       0.0  2022-06-29T18:48:39.172-04:00
#
#        cod_aut t_tarjeta  n_ctas   c_ctas  n_tarjetas
# 49    194884.0        VD     0.0      0.0         1.0
# 56    999429.0        VD     0.0      0.0         1.0
# 57    590542.0        VD     0.0      0.0         1.0
# 58    755976.0        VD     0.0      0.0         1.0
# 59    159123.0        VD     0.0      0.0         1.0
# ...        ...       ...     ...      ...         ...
# 1145  500963.0        VN     0.0      0.0       978.0
# 1147  972619.0        SI     3.0  36634.0      6460.0
# 1148  531404.0        VC    12.0      0.0      1609.0
# 1149  747225.0        NC     6.0  62300.0      2095.0
# 1150  895841.0        NC     6.0  36634.0       768.0
#
# [497 rows x 11 columns]

# %%
demo.t_tarjeta.value_counts()
# Out:
# VD    267
# 0      97
# NC     60
# VN     40
# SI     28
# VC      5
# Name: t_tarjeta, dtype: int64

# %%
demo.t_tarjeta = pd.Categorical(demo.t_tarjeta, categories=["VD", "0","NC","VN","SI","VC"])

# %%
demo.dtypes
# Out:
# id               int64
# oc               int64
# total            int64
# estado           int64
# response       float64
# fetchtbk        object
# cod_aut        float64
# t_tarjeta     category
# n_ctas         float64
# c_ctas         float64
# n_tarjetas     float64
# dtype: object

# %%
demo.response.value_counts()
# Out:
#  0.0    401
# -1.0     58
# -3.0     20
# -2.0     17
# -4.0      1
# Name: response, dtype: int64

# %%
demo.response = pd.cut(demo.response, bins=5, labels=False)

# %%
demo.cod_aut.value_counts()
# Out:
# 0.0         97
# 1213.0       3
# 123080.0     3
# 113334.0     2
# 122610.0     2
#             ..
# 200426.0     1
# 100827.0     1
# 431508.0     1
# 105406.0     1
# 895841.0     1
# Name: cod_aut, Length: 387, dtype: int64

# %%
demo = demo.drop("cod_aut",1)
# Out:
# C:\Users\taois\AppData\Local\Temp\ipykernel_8652\2775792793.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   demo = demo.drop("cod_aut",1)

# %%
demo
# Out:
#         id    oc    total  estado  response                       fetchtbk  \
# 49      50   131   254420       1         4  2020-06-15T14:03:43.118-04:00
# 56      57   139   254420       1         4  2020-06-15T14:18:45.988-04:00
# 57      58   140   254420       1         4  2020-06-15T14:20:13.448-04:00
# 58      59   141   254420       1         4  2020-06-15T14:25:38.911-04:00
# 59      60   142   254420       1         4  2020-06-15T15:11:43.928-04:00
# ...    ...   ...      ...     ...       ...                            ...
# 1145  1146  1267   389801       1         4  2022-06-28T09:48:26.694-04:00
# 1147  1148  1269   109900       1         4  2022-06-28T15:25:50.355-04:00
# 1148  1149  1270  1869002       1         4  2022-06-28T20:34:45.153-04:00
# 1149  1150  1271   373800       1         4  2022-06-28T20:39:35.849-04:00
# 1150  1151  1272   219800       1         4  2022-06-29T18:48:39.172-04:00
#
#      t_tarjeta  n_ctas   c_ctas  n_tarjetas
# 49          VD     0.0      0.0         1.0
# 56          VD     0.0      0.0         1.0
# 57          VD     0.0      0.0         1.0
# 58          VD     0.0      0.0         1.0
# 59          VD     0.0      0.0         1.0
# ...        ...     ...      ...         ...
# 1145        VN     0.0      0.0       978.0
# 1147        SI     3.0  36634.0      6460.0
# 1148        VC    12.0      0.0      1609.0
# 1149        NC     6.0  62300.0      2095.0
# 1150        NC     6.0  36634.0       768.0
#
# [497 rows x 10 columns]

# %%
demo.dtypes
# Out:
# id               int64
# oc               int64
# total            int64
# estado           int64
# response         int64
# fetchtbk        object
# t_tarjeta     category
# n_ctas         float64
# c_ctas         float64
# n_tarjetas     float64
# dtype: object

# %%
demo.n_ctas = demo.n_ctas.apply(np.int64)
demo.c_ctas = demo.c_ctas.apply(np.int64)
demo.n_tarjetas = demo.n_tarjetas.apply(np.int64)

# %%
demo.fetchtbk = pd.to_datetime(demo.fetchtbk, errors = "coerce")

# %%
demo.dtypes
# Out:
# id               int64
# oc               int64
# total            int64
# estado           int64
# response         int64
# fetchtbk        object
# t_tarjeta     category
# n_ctas           int64
# c_ctas           int64
# n_tarjetas       int64
# dtype: object

# %%
demo.head(1000)
# Out:
#         id    oc    total  estado  response                       fetchtbk  \
# 49      50   131   254420       1         4  2020-06-15T14:03:43.118-04:00
# 56      57   139   254420       1         4  2020-06-15T14:18:45.988-04:00
# 57      58   140   254420       1         4  2020-06-15T14:20:13.448-04:00
# 58      59   141   254420       1         4  2020-06-15T14:25:38.911-04:00
# 59      60   142   254420       1         4  2020-06-15T15:11:43.928-04:00
# ...    ...   ...      ...     ...       ...                            ...
# 1145  1146  1267   389801       1         4  2022-06-28T09:48:26.694-04:00
# 1147  1148  1269   109900       1         4  2022-06-28T15:25:50.355-04:00
# 1148  1149  1270  1869002       1         4  2022-06-28T20:34:45.153-04:00
# 1149  1150  1271   373800       1         4  2022-06-28T20:39:35.849-04:00
# 1150  1151  1272   219800       1         4  2022-06-29T18:48:39.172-04:00
#
#      t_tarjeta  n_ctas  c_ctas  n_tarjetas
# 49          VD       0       0           1
# 56          VD       0       0           1
# 57          VD       0       0           1
# 58          VD       0       0           1
# 59          VD       0       0           1
# ...        ...     ...     ...         ...
# 1145        VN       0       0         978
# 1147        SI       3   36634        6460
# 1148        VC      12       0        1609
# 1149        NC       6   62300        2095
# 1150        NC       6   36634         768
#
# [497 rows x 10 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\Documents\proyectos\curso_uc\env\lib\site-packages\sklearn\utils\_encode.py:173, in _unique_python(values, return_inverse, return_counts)
#     171 uniques_set, missing_values = _extract_missing(uniques_set)
# --> 173 uniques = sorted(uniques_set)
#     174 uniques.extend(missing_values.to_list())
#
# TypeError: '<' not supported between instances of 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Input In [68], in <cell line: 6>()
#       4 labelencoder = LabelEncoder()
#       6 for i in columns:
# ----> 7     df[i] = labelencoder.fit_transform(df[i])
#       9 df.head()
#
# File ~\Documents\proyectos\curso_uc\env\lib\site-packages\sklearn\preprocessing\_label.py:116, in LabelEncoder.fit_transform(self, y)
#     103 """Fit label encoder and return encoded labels.
#     104
#     105 Parameters
#    (...)
#     113     Encoded labels.
#     114 """
#     115 y = column_or_1d(y, warn=True)
# --> 116 self.classes_, y = _unique(y, return_inverse=True)
#     117 return y
#
# File ~\Documents\proyectos\curso_uc\env\lib\site-packages\sklearn\utils\_encode.py:41, in _unique(values, return_inverse, return_counts)
#      10 """Helper function to find unique values with support for python objects.
#      11
#      12 Uses pure python method for object dtype, and numpy method for
#    (...)
#      38     array. Only provided if `return_counts` is True.
#      39 """
#      40 if values.dtype == object:
# ---> 41     return _unique_python(
#      42         values, return_inverse=return_inverse, return_counts=return_counts
#      43     )
#      44 # numerical
#      45 return _unique_np(
#      46     values, return_inverse=return_inverse, return_counts=return_counts
#      47 )
#
# File ~\Documents\proyectos\curso_uc\env\lib\site-packages\sklearn\utils\_encode.py:178, in _unique_python(values, return_inverse, return_counts)
#     176 except TypeError:
#     177     types = sorted(t.__qualname__ for t in set(type(v) for v in values))
# --> 178     raise TypeError(
#     179         "Encoders require their input to be uniformly "
#     180         f"strings or numbers. Got {types}"
#     181     )
#     182 ret = (uniques,)
#     184 if return_inverse:
#
# TypeError: Encoders require their input to be uniformly strings or numbers. Got ['int', 'str']

# %%
# Out:
# 1106    1228
# 573      683
# 422      517
# 228      322
# 321      415
#         ...
# 253      347
# 623      735
# 829      944
# 1021    1139
# 244      338
# Name: oc, Length: 248, dtype: int64

# %%
# Out:
# 1106    379800
# 573     628030
# 422          1
# 228     535500
# 321     280207
#          ...
# 253     807002
# 623     305878
# 829     311799
# 1021    183177
# 244     150546
# Name: total, Length: 248, dtype: int64
