# %%
# test random forest

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import pydotplus
import graphviz
import seaborn as sn

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn import tree

from sklearn import preprocessing
# %matplotlib notebook

# %%
lab = preprocessing.LabelEncoder()

# %%
# improtar datos

# %%
df1 = pd.read_csv("Features data set.csv", sep=",")
df2 = pd.read_csv("sales data-set.csv", sep=",")
df_ventas_tienda = pd.read_csv("Tabla_1.csv")

# %%
df1.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  05/02/2010        42.31       2.572        NaN        NaN
# 1      1  12/02/2010        38.51       2.548        NaN        NaN
# 2      1  19/02/2010        39.93       2.514        NaN        NaN
# 3      1  26/02/2010        46.63       2.561        NaN        NaN
# 4      1  05/03/2010        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %%
df1.columns.tolist()
# Out:
# ['Store',
#  'Date',
#  'Temperature',
#  'Fuel_Price',
#  'MarkDown1',
#  'MarkDown2',
#  'MarkDown3',
#  'MarkDown4',
#  'MarkDown5',
#  'CPI',
#  'Unemployment',
#  'IsHoliday']

# %%
df2.columns.tolist()
# Out:
# ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']

# %%
# Merge dataframe

# %%
df1.merge(df2, on="Store")
# Out:
#           Store      Date_x  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0             1  05/02/2010        42.31       2.572        NaN        NaN
# 1             1  05/02/2010        42.31       2.572        NaN        NaN
# 2             1  05/02/2010        42.31       2.572        NaN        NaN
# 3             1  05/02/2010        42.31       2.572        NaN        NaN
# 4             1  05/02/2010        42.31       2.572        NaN        NaN
# ...         ...         ...          ...         ...        ...        ...
# 76725735     45  26/07/2013        76.06       3.804     212.02     851.73
# 76725736     45  26/07/2013        76.06       3.804     212.02     851.73
# 76725737     45  26/07/2013        76.06       3.804     212.02     851.73
# 76725738     45  26/07/2013        76.06       3.804     212.02     851.73
# 76725739     45  26/07/2013        76.06       3.804     212.02     851.73
#
# ...

# %%
# get muestra

# %%
df_sample = df1.sample(n=100)

# %%
df_sample = df_sample.fillna(0)

# %%
df_sample
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 5726     32  16/09/2011        60.88       3.596       0.00       0.00
# 153       1  11/01/2013        50.32       3.243    6520.24   16134.60
# 6581     37  27/08/2010        84.62       2.619       0.00       0.00
# 2039     12  22/10/2010        68.85       3.014       0.00       0.00
# 3141     18  31/12/2010        26.10       3.177       0.00       0.00
# ...     ...         ...          ...         ...        ...        ...
# 7953     44  13/07/2012        83.68       3.595     372.75       0.00
# 6149     34  02/11/2012        50.91       3.404    3189.15    2375.99
# 5255     29  22/02/2013        30.28       3.866   14443.78    1340.14
# 6681     37  27/07/2012        84.00       3.407      22.21       0.00
# 546       4  05/02/2010        43.76       2.598       0.00       0.00
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...

# %%
# Variables categoricas
df_sample.iloc[:, 11]
# Out:
# 5726    False
# 153     False
# 6581    False
# 2039    False
# 3141     True
#         ...
# 7953    False
# 6149    False
# 5255    False
# 6681    False
# 546     False
# Name: IsHoliday, Length: 100, dtype: bool

# %%
df_sample
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 5726     32  16/09/2011        60.88       3.596       0.00       0.00
# 153       1  11/01/2013        50.32       3.243    6520.24   16134.60
# 6581     37  27/08/2010        84.62       2.619       0.00       0.00
# 2039     12  22/10/2010        68.85       3.014       0.00       0.00
# 3141     18  31/12/2010        26.10       3.177       0.00       0.00
# ...     ...         ...          ...         ...        ...        ...
# 7953     44  13/07/2012        83.68       3.595     372.75       0.00
# 6149     34  02/11/2012        50.91       3.404    3189.15    2375.99
# 5255     29  22/02/2013        30.28       3.866   14443.78    1340.14
# 6681     37  27/07/2012        84.00       3.407      22.21       0.00
# 546       4  05/02/2010        43.76       2.598       0.00       0.00
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...

# %%
# https://www.youtube.com/watch?v=jlJ4uKS9D5A&t=666s

# %%
df = df_sample.merge(df2, on="Store")

# %%
df
# Out:
#         Store      Date_x  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0          32  16/09/2011        60.88       3.596        0.0        0.0
# 1          32  16/09/2011        60.88       3.596        0.0        0.0
# 2          32  16/09/2011        60.88       3.596        0.0        0.0
# 3          32  16/09/2011        60.88       3.596        0.0        0.0
# 4          32  16/09/2011        60.88       3.596        0.0        0.0
# ...       ...         ...          ...         ...        ...        ...
# 912634      4  05/02/2010        43.76       2.598        0.0        0.0
# 912635      4  05/02/2010        43.76       2.598        0.0        0.0
# 912636      4  05/02/2010        43.76       2.598        0.0        0.0
# 912637      4  05/02/2010        43.76       2.598        0.0        0.0
# 912638      4  05/02/2010        43.76       2.598        0.0        0.0
#
#         MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  \
# ...

# %%
# seleccion datos que solamente se van a usar

# %%
df_filter = df[["Store", "IsHoliday_y", "Weekly_Sales"]]

# %%
df_filter.head()
# Out:
#    Store  IsHoliday_y  Weekly_Sales
# 0     32        False      22675.43
# 1     32         True      36390.07
# 2     32        False      25515.17
# 3     32        False      18008.32
# 4     32        False      19313.36

# %%
# infor

# %%
df_filter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 912639 entries, 0 to 912638
# Data columns (total 3 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         912639 non-null  int64
#  1   IsHoliday_y   912639 non-null  bool
#  2   Weekly_Sales  912639 non-null  float64
# dtypes: bool(1), float64(1), int64(1)
# memory usage: 21.8 MB

# %%
# datos de entrenamiento y test

# %%
# variable independiente
X = df_filter.drop(["IsHoliday_y"], axis= 1)
#variable dependiente
y = df_filter.Weekly_Sales
# 70 - 30
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %%
##### modelo

# %%
cif = RandomForestClassifier(n_estimators = 10, random_state = 2016, min_samples_leaf = 8)

# %%
cif
# Out:
# RandomForestClassifier(min_samples_leaf=8, n_estimators=10, random_state=2016)

# %%
cif.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [77], in <cell line: 1>()
# ----> 1 cif.fit(X_train, y_train)
#
# File ~\Documents\proyectos\curso_uc\env\lib\site-packages\sklearn\ensemble\_forest.py:371, in BaseForest.fit(self, X, y, sample_weight)
#     364         raise ValueError(
#     365             "Sum of y is not strictly positive which "
#     366             "is necessary for Poisson regression."
#     367         )
#     369 self.n_outputs_ = y.shape[1]
# --> 371 y, expanded_class_weight = self._validate_y_class_weight(y)
#     373 if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
#     374     y = np.ascontiguousarray(y, dtype=DOUBLE)
#
# File ~\Documents\proyectos\curso_uc\env\lib\site-packages\sklearn\ensemble\_forest.py:758, in ForestClassifier._validate_y_class_weight(self, y)
#     757 def _validate_y_class_weight(self, y):
# ...
